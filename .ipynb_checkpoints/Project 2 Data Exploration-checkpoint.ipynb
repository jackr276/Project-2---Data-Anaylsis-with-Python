# %% [markdown]
# # Jack Robbins
# ## 09/28/2022
# ### Project 2 Data Exploration

# %% [markdown]
# Import pandas, matplotlib, math and statistsics for use in data cleaning and analysisi

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import statistics as stats

# %% [markdown]
# Assign all of the csv files more manageable names, then read them all in with the parses date options set to true

# %%
entry_2020 = "CCM Computing Entry Survey - Fall 2020.csv"
entry_2021 = "CCM Computing Entry Survey - Fall 2021.csv"
literacy_2020 = "CCM Computing Literacy Course Entry Survey - Fall 2020.csv"
literacy_2021 = "CCM Computing Literacy Course Entry Survey - Fall 2021.csv"

# %%
df_entry_2020 = pd.read_csv("CCM Computing Entry Survey - Fall 2020.csv", parse_dates = True)
df_entry_2021 = pd.read_csv("CCM Computing Entry Survey - Fall 2021.csv", parse_dates = True)
df_literacy_2020 = pd.read_csv("CCM Computing Literacy Course Entry Survey - Fall 2020.csv", parse_dates = True)
df_literacy_2021 = pd.read_csv("CCM Computing Literacy Course Entry Survey - Fall 2021.csv", parse_dates = True)

# %% [markdown]
# Rename the columns that are going to be used in the 2020 entry survey, then create a subset with only the renamed columns for use in the analysis

# %%
df_entry_2020.columns
df_entry_2021.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %%
df_entry_2020.rename(columns = {"Timestamp": "timestamp","Which course are you enrolled in?": "coursename", "What degree program are you currently enrolled in?": "degree", "What motivated you to seek a computing degree/certificate at CCM? (check all that apply)": "motivated_degree", "Did you receive information about the CCM computing programs from any of the following sources? [High school guidance counselor]":"heard_hs_counselor", "Did you receive information about the CCM computing programs from any of the following sources? [High School Teacher]":"heard_hs_teacher", "Did you receive information about the CCM computing programs from any of the following sources? [CCM Information Technologies Website]":"heard_it_website", "Did you receive information about the CCM computing programs from any of the following sources? [CCM Admissions]":"heard_ccm_admissions", "Did you receive information about the CCM computing programs from any of the following sources? [CCM advisor/counselor]": "heard_ccm_advisor", "Did you receive information about the CCM computing programs from any of the following sources? [Employer]":"heard_employer", "Did you receive information about the CCM computing programs from any of the following sources? [CCM Workforce Development]":"heard_work_dev", "Did you receive information about the CCM computing programs from any of the following sources? [NJ Workforce Development Program]":"heard_nj_work_dev","Was a computing major/certificate your first choice, or did you change majors from a different CCM program? If you changed majors, indicate what your first major was.": "first_choice","On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?":"interest_level", "Race/ethnicity": "race", "Age ":"age", "Gender":"gender"}, inplace = True)
data_2020 = df_entry_2020[["timestamp", "coursename", "degree", "motivated_degree","heard_hs_counselor", "heard_hs_teacher", "heard_it_website","heard_ccm_admissions", "heard_employer", "heard_work_dev", "heard_nj_work_dev", "first_choice", "interest_level", "race", "gender"]]
data_2020
# Out:
#                       timestamp                                    coursename  \
# 0     2020/07/28 3:21:36 PM EST            CMP 239 Internet & Web Page Design
# 1     2020/07/28 4:07:22 PM EST            CMP 239 Internet & Web Page Design
# 2     2020/07/28 8:12:47 PM EST            CMP 239 Internet & Web Page Design
# 3    2020/07/29 10:53:03 AM EST            CMP 239 Internet & Web Page Design
# 4     2020/07/29 4:26:21 PM EST            CMP 239 Internet & Web Page Design
# ..                          ...                                           ...
# 293   2020/10/13 5:07:17 PM EST                           CMP 130 Intro to IT
# 294  2020/10/14 10:08:02 AM EST  CMP 131 Fundamentals of Programming (Python)
# 295   2020/10/14 6:18:25 PM EST  CMP 131 Fundamentals of Programming (Python)
# 296   2020/10/22 6:59:06 PM EST                    CMP 128 Computer Science I
# 297   2020/10/26 1:27:44 PM EST                    CMP 128 Computer Science I
#
# ...

# %% [markdown]
# Repeat the process for the 2021 entry survey, renaming columns to the same names so that we can concatenate the two

# %%
df_entry_2021.rename(columns = {"Timestamp": "timestamp","Which course are you enrolled in?": "coursename", "What degree program are you currently enrolled in?": "degree", "What motivated you to seek a computing degree/certificate at CCM? (check all that apply)": "motivated_degree", "Did you receive information about the CCM computing programs from any of the following sources? [High school guidance counselor]":"heard_hs_counselor", "Did you receive information about the CCM computing programs from any of the following sources? [High School Teacher]":"heard_hs_teacher", "Did you receive information about the CCM computing programs from any of the following sources? [CCM Information Technologies Website]":"heard_it_website", "Did you receive information about the CCM computing programs from any of the following sources? [CCM Admissions]":"heard_ccm_admissions", "Did you receive information about the CCM computing programs from any of the following sources? [CCM advisor/counselor]": "heard_ccm_advisor", "Did you receive information about the CCM computing programs from any of the following sources? [Employer]":"heard_employer", "Did you receive information about the CCM computing programs from any of the following sources? [CCM Workforce Development]":"heard_work_dev", "Did you receive information about the CCM computing programs from any of the following sources? [NJ Workforce Development Program]":"heard_nj_work_dev","Was a computing major/certificate your first choice, or did you change majors from a different CCM program? If you changed majors, indicate what your first major was.": "first_choice","On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?":"interest_level", "Race/ethnicity": "race", "Age ":"age", "Gender":"gender"}, inplace = True)
data_2021 = df_entry_2020[["timestamp", "coursename", "degree", "motivated_degree","heard_hs_counselor", "heard_hs_teacher", "heard_it_website","heard_ccm_admissions", "heard_employer", "heard_work_dev", "heard_nj_work_dev", "first_choice", "interest_level", "race", "gender"]]
data_2021
# Out:
#                       timestamp                                    coursename  \
# 0     2020/07/28 3:21:36 PM EST            CMP 239 Internet & Web Page Design
# 1     2020/07/28 4:07:22 PM EST            CMP 239 Internet & Web Page Design
# 2     2020/07/28 8:12:47 PM EST            CMP 239 Internet & Web Page Design
# 3    2020/07/29 10:53:03 AM EST            CMP 239 Internet & Web Page Design
# 4     2020/07/29 4:26:21 PM EST            CMP 239 Internet & Web Page Design
# ..                          ...                                           ...
# 293   2020/10/13 5:07:17 PM EST                           CMP 130 Intro to IT
# 294  2020/10/14 10:08:02 AM EST  CMP 131 Fundamentals of Programming (Python)
# 295   2020/10/14 6:18:25 PM EST  CMP 131 Fundamentals of Programming (Python)
# 296   2020/10/22 6:59:06 PM EST                    CMP 128 Computer Science I
# 297   2020/10/26 1:27:44 PM EST                    CMP 128 Computer Science I
#
# ...

# %% [markdown]
# Concatenate the two entry survey dataframes, so that there is one large entry survey to be cleaned

# %%
entry_survey = pd.concat([data_2020, data_2021], axis = 0).reset_index()
entry_survey
# Out:
#      index                   timestamp  \
# 0        0   2020/07/28 3:21:36 PM EST
# 1        1   2020/07/28 4:07:22 PM EST
# 2        2   2020/07/28 8:12:47 PM EST
# 3        3  2020/07/29 10:53:03 AM EST
# 4        4   2020/07/29 4:26:21 PM EST
# ..     ...                         ...
# 591    293   2020/10/13 5:07:17 PM EST
# 592    294  2020/10/14 10:08:02 AM EST
# 593    295   2020/10/14 6:18:25 PM EST
# 594    296   2020/10/22 6:59:06 PM EST
# 595    297   2020/10/26 1:27:44 PM EST
#
#                                        coursename  \
# 0              CMP 239 Internet & Web Page Design
# 1              CMP 239 Internet & Web Page Design
# 2              CMP 239 Internet & Web Page Design
# 3              CMP 239 Internet & Web Page Design
# 4              CMP 239 Internet & Web Page Design
# ..                                            ...
# 591                           CMP 130 Intro to IT
# 592  CMP 131 Fundamentals of Programming (Python)
# ...

# %%
df_literacy_2020.columns
df_literacy_2021.columns
# Out:
# Index(['Timestamp', 'Timestamp.1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Which course are you currently enrolled in?',
#        'What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]',
#        'What motivated you to seek a computing class at CCM? [To keep current in computing skills]',
#        'What motivated you to seek a computing class at CCM? [Career Advancement]',
#        'What motivated you to seek a computing class at CCM? [Career Change]',
#        'What motivated you to seek a computing class at CCM? [Professional Development]',
#        'What motivated you to seek a computing class at CCM? [Job Displacement]',
#        'What motivated you to seek a computing class at CCM? [Relocation]',
#        'What motivated you to seek a computing class at CCM? [IT Industry Certifications]',
#        'What motivated you to seek a computing class at CCM? [Financial]',
# ...

# %%
df_literacy_2020.rename(columns = {"Timestamp": "timestamp", "Which course are you currently enrolled in?":"coursename", "What degree program are you currently enrolled in?": "degree", "Did you receive information about our computing course from any of the following sources? [High school guidance counselor]":"heard_hs_counselor", "Did you receive information about our computing course from any of the following sources? [CCM Information Technologies Website]":"heard_it_website", "Did you receive information about our computing course from any of the following sources? [CCM Admissions]":"heard_ccm_admissions", "id you receive information about our computing course from any of the following sources? [CCM advisor/counselor]":"heard_ccm_advisor", "Did you receive information about our computing course from any of the following sources? [Employer]":"heard_employer", "On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?": "interest_level", "Computing Interest": "comp_int", "If you answered that you were interested in taking more computing classes, which ones interest you most? [Web Development]": "interest_web_dev", "If you answered that you were interested in taking more computing classes, which ones interest you most? [App Development]": "interest_app_dev", "If you answered that you were interested in taking more computing classes, which ones interest you most? [Data Analytics]":"interest_data", "If you answered that you were interested in taking more computing classes, which ones interest you most? [Machine Learning/Artificial Intelligence]":"interst_ai", "If you answered that you were interested in taking more computing classes, which ones interest you most? [Game Design]":"interest_game_dev", "If you answered that you were interested in taking more computing classes, which ones interest you most? [Computer Programming]":"interest_comp_prog", "If you answered that you were interested in taking more computing classes, which ones interest you most? [Hardware Installation & Repair]":"interest_hardware", "Gender":"gender", "Age ":"age"}, inplace=True)

# %%
df_entry_2020.tail()
df_entry_2021.tail()
df_literacy_2020.tail()
df_literacy_2021.tail()

# %%
df_entry_2020.shape
df_entry_2021.shape
df_literacy_2020.shape
df_literacy_2021.shape

# %%
df_entry_2020.columns
df_entry_2021.columns
df_literacy_2020.columns
df_literacy_2021.columns

# %%
df_entry_2020.count()
df_entry_2021.count()
df_literacy_2020.count()
df_literacy_2021.count()

# %%
df_entry_2020.describe()
df_entry_2021.describe()
df_literacy_2020.describe()
df_literacy_2021.describe()

# %%
df_entry_2020.info()
df_entry_2021.info()
df_literacy_2020.info()
df_literacy_2021.info()

df_entry_2020.rename(columns = {'Race/Ethinicity': 'Race'}, inplace = True) #change individual column names by using a dictionary
df_entry_2020
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298 entries, 0 to 297
# Data columns (total 79 columns):
#  #   Column                                                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                           --------------  -----
#  0   Timestamp                                                                                                                                                                                                                                                        298 non-null    object
# ...

# %%
subset = df_literacy_2021.iloc[:, 1:15]
subset.columns = ['Date', 'number', 'time', "AM/PM", "Timezone", "Coursename", 'motivated_degree', 'motivated_skills', 'motivated_career', 'motivated_career_change', 'motivated_prof_dev', 'motivated_job-disp', 'motivated_reloc', 'motivated_IT_cert']
subset
# Out:
#            Date  number      time AM/PM Timezone  \
# 0     10/4/2021     2.0   1:43:00    PM      EST
# 1     10/4/2021     2.0   2:15:38    PM      EST
# 2     10/4/2021     2.0   3:06:08    PM      EST
# 3     10/4/2021     2.0   6:32:07    PM      EST
# 4     10/5/2021     3.0   7:22:53    PM      EST
# ..          ...     ...       ...   ...      ...
# 121  11/26/2021     6.0  10:47:11    AM      EST
# 122         NaN     NaN       NaN   NaN      NaN
# 123         NaN     NaN       NaN   NaN      NaN
# 124         NaN     NaN       NaN   NaN      NaN
# 125         NaN     NaN       NaN   NaN      NaN
#
#                                        Coursename motivated_degree  \
# 0    CMP 126 Computer Technology and Applications              Yes
# 1    CMP 126 Computer Technology and Applications              Yes
# 2    CMP 126 Computer Technology and Applications               No
# 3           CMP 101 Computer Information Literacy              Yes
# ...

# %%
CMP126_subset = subset[subset.Coursename!="CMP 239 Internet & Web Page Design"]
CMP126_subset
# Out:
#            Date  number      time AM/PM Timezone  \
# 0     10/4/2021     2.0   1:43:00    PM      EST
# 1     10/4/2021     2.0   2:15:38    PM      EST
# 2     10/4/2021     2.0   3:06:08    PM      EST
# 3     10/4/2021     2.0   6:32:07    PM      EST
# 4     10/5/2021     3.0   7:22:53    PM      EST
# ..          ...     ...       ...   ...      ...
# 121  11/26/2021     6.0  10:47:11    AM      EST
# 122         NaN     NaN       NaN   NaN      NaN
# 123         NaN     NaN       NaN   NaN      NaN
# 124         NaN     NaN       NaN   NaN      NaN
# 125         NaN     NaN       NaN   NaN      NaN
#
#                                        Coursename motivated_degree  \
# 0    CMP 126 Computer Technology and Applications              Yes
# 1    CMP 126 Computer Technology and Applications              Yes
# 2    CMP 126 Computer Technology and Applications               No
# 3           CMP 101 Computer Information Literacy              Yes
# ...
